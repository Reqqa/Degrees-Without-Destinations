# %% [markdown]
# # Degrees Without Destinations
# ###  Uncovering Malaysia's Graduate Employment Crisis Across States, Fields, and Income Groups
# Summary:
# Malaysia is producing more graduates than ever, but the wrong ones, in the wrong places, for jobs that don't pay enough.
